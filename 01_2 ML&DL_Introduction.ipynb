# %% [markdown]
# For this task we use Mammographic Mass dataset.
#
# https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset
#
# Dataset of simulated mushrooms for binary classification into edible and poisonous.

# %% [markdown]
# # Imports

# %% [markdown]
# # Load Data

# %% [markdown]
# # Data Insights

# %% [markdown]
# # Target Encoding

# %% [markdown]
# # Dataset Split

# %% [markdown]
# # Missing Values

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# # Categorical Encoding

# %% [markdown]
# # Scaling

# %% [markdown]
# # Over- / Undersampling

# %% [markdown]
# # Modelling

# %% [markdown]
# # Testing
